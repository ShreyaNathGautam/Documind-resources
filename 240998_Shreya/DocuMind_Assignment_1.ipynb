# %% [markdown]
# #Assignment 1
# Using AI tools is allowed, but should be done responsibly. Don't simply copy and paste generated answers. AI can be helpful for understanding syntax, functionality, or concepts, but you should put in genuine effort to debug and solve problems yourself.
#
# Ultimately, you are the one who benefits most from the learning and understanding you gain.

# %% [markdown]
# ### Python and NumPy Assignment: Data Analysis Fundamentals
#
# This assignment has two main parts. Part 1 covers core Python skills, and Part 2 introduces basic NumPy operations. Part 3 is an optional bonus problem — completing it is strongly encouraged since these concepts will come up frequently going forward.

# %% [markdown]
# ### Part 1: Python List Operations
#
# **Objective**: Write a Python function that processes a list of numbers.
#
# **Scenario**: You have a week's worth of daily temperature readings (in Celsius). Your task is to find the days that exceeded a given threshold and compute their average.
#
# **Instructions**:
# 1.  **Run the setup cell below** to create the `daily_temperatures` list and `temperature_threshold` variable.
# 2.  **Write a function** called `analyze_temperatures` that accepts two parameters: a list of temperatures and a threshold value.
# 3.  **Within the function**:
#     *   Find every temperature that is *strictly greater* than the threshold.
#     *   If any such temperatures exist, compute their average.
#     *   Return the above-threshold temperatures along with their average. If none exist, return an empty list and `None` in place of the average.
# 4.  **Invoke the function** using `daily_temperatures` and `temperature_threshold`.
# 5.  **Display** the output in a clear, readable way.

# %%
# Pre-code for Part 1
daily_temperatures = [22, 25, 19, 28, 23, 30, 26] # Temperatures in Celsius
temperature_threshold = 24

# %%
# Your code for Part 1 goes here

def analyze_temperatures(temperatures, threshold):
    # TODO: Implement the function as per instructions

    pass

# TODO: Call the function and print results

# %% [markdown]
# #### Part 1 (Continued): Random List Generation and Analysis
#
# **Objective**: Create several lists of random integers and run basic statistics on them.
#
# **Instructions**:
# 1.  **Create 10 separate lists**, each holding 5 random integers ranging from 1 to 100 (inclusive).
# 2.  For every one of these 10 lists:
#     *   Compute the **sum** of its values.
#     *   Compute the **average** of its values.
# 3.  Determine which list has the **largest sum** out of all 10, and print that list together with its sum and average.

# %%
import random

# Your code for Part 1 (Continued) goes here

# TODO: Generate 10 lists of random integers

# TODO: Calculate sum and average for each list

# TODO: Find and print the list with the highest sum

# %% [markdown]
# ### Part 2: Introduction to NumPy
#
# **Objective**: Get some practical experience with NumPy for numerical computation, including setting it up.
#
# **Scenario**: You'd like to run faster, more efficient calculations on the temperature dataset using NumPy instead of plain Python.
#
# **Instructions**:
# 1.  **Install NumPy** by running the `pip install numpy` command below.
# 2.  **Import NumPy** into your environment.
# 3.  **Turn** the `daily_temperatures` list from Part 1 into a NumPy array.
# 4.  **With NumPy functions**:
#     *   Determine the **maximum** temperature.
#     *   Compute the **standard deviation** of the temperatures.
#     *   Build a new array holding only the temperatures **greater than or equal to 25**.
# 5.  **Print** the results so it's clear which value belongs to which calculation.

# %%
# Step 1: Install NumPy (run this cell)
# !pip install numpy

# %%
# Your code for Part 2 goes here

# TODO: Import NumPy

# TODO: Convert daily_temperatures to a NumPy array

# TODO: Perform NumPy operations and print results

# %% [markdown]
# ### Part 3: Bonus Problem - Object-Oriented Book Management
#
# **Objective**: Get hands-on with object-oriented programming (`class`, `__init__`) by building a `Book` class and working with a group of books.
#
# **Scenario**: You're organizing a small library's collection and want to structure the book data using Python classes.
#
# **Instructions**:
# 1.  **Create a `Book` class** whose `__init__` method accepts `title` and `author`, storing each as an instance attribute.
# 2.  **Build a list of `Book` objects** from the given `book_data`.
# 3.  **Write logic** (as a class method or standalone function) to:
#     *   Identify the book with the **longest title**.
#     *   List every book by a given author (e.g., 'George Orwell').
# 4.  **Print** the results clearly and legibly.

# %%
# Pre-code for Part 3
book_data = [
    {'title': '1984', 'author': 'George Orwell'},
    {'title': 'Brave New World', 'author': 'Aldous Huxley'},
    {'title': 'Animal Farm', 'author': 'George Orwell'},
    {'title': 'The Great Gatsby', 'author': 'F. Scott Fitzgerald'},
    {'title': 'To Kill a Mockingbird', 'author': 'Harper Lee'}
]

# Your code for Part 3 goes here

# TODO: Define the Book class

# TODO: Create Book objects and perform operations

# TODO: Print results
